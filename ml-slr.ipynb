# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load datasets
df=pd.read_csv("C:/Users/Dell/OneDrive/Desktop/COE/Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
#check for missing values
df.isna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
#distribution of the numerical data with histpgram
sns.histplot(x=df['Unnamed: 0'],kde='True',bins=14)
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Count'>

# %%
sns.histplot(x=df['TV'],kde='True',bins=14)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'],kde='True',bins=14)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'],kde='True',bins=14)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'],kde='True',bins=14)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# if the skvalue is 0 it is normal and if the value is negative it is left/negatively skewed and
# if the value is positive it is right/positively skewed but it is not possible to gave all the values to be exactly 0 so we will take all the values which are between -0.5 to +0.5 we will consider it as normal and values outside this range is considered as skewed.

# %%
df['Unnamed: 0'].skew(0)   #ideal/normal distribution cause the value is 0
# Out:
# np.float64(0.0)

# %%
df['TV'].skew(0)    #normal distribution cause the value is in between -0.5 to +0.5
# Out:
# np.float64(-0.06985336213274573)

# %%
df['Radio'].skew(0)   #normal distribution cause the value is in between -0.5 to +0.5
# Out:
# np.float64(0.09417463149664404)

# %%
df['Newspaper'].skew(0)      #positive/right skewed cause the value is greater than +0.5
# Out:
# np.float64(0.8947204074986175)

# %%
df['Sales'].skew(0)           #normal distribution cause the value is in between -0.5 to +0.5
# Out:
# np.float64(0.4075714250767127)

# %% [markdown]
# we need to see the relationship between the output column with the other columns,
# for two numeric values we use the scatterplot,it will only give what type of relation they have but not to what extent like strong or weak etc

# %%
plt.figure()
sns.scatterplot(x=df['Unnamed: 0'],y=df['Sales'])
plt.show()
#they have a random relationship

# %%
plt.figure()
sns.scatterplot(x=df['TV'],y=df['Sales'])
plt.show()
#they have a positive relationship

# %%
plt.figure()
sns.scatterplot(x=df['Radio'],y=df['Sales'])
plt.show()
#they have a positive relationship

# %%
plt.figure()
sns.scatterplot(x=df['Newspaper'],y=df['Sales'])
plt.show()
#they have a positive relationship

# %%
#to know the extent of the relationship we use correlation coefficient matrix

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# TV vs Sales: Positive — because sales increase when TV advertising increases.
#
# Radio vs Sales: Positive — because higher radio ads generally lead to higher sales.
#
# Newspaper vs Sales: Positive — because changes in newspaper spending do not clearly affect sales,not very much.
#
# Unnamed vs Sales: Random — because it is just an index number and has no real impact on sales.

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# Simple linear regression

# %%
#step1 Independent and dependent variable creations
x=df[['TV']] # x variable contains one feature
y=df.Sales # y is target

# %%
#step 2 splitting the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
#step 3 creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression()  #object creation
LR.fit(x_train,y_train)  #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 13.06226628830567
# MAE: 2.990565035759226
# RMSE: 3.6141757412037494

# %%
x=df[['Radio']] # x variable contains one feature
y=df.Sales # y is target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()  #object creation
LR.fit(x_train,y_train)  #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 15.068910882943161
# MAE: 3.268917036469783
# RMSE: 3.881869508747449

# %%
x=df[['Newspaper']] # x variable contains one feature
y=df.Sales # y is target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()  #object creation
LR.fit(x_train,y_train)  #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004906

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 27.096125475528662
# MAE: 3.992290912504232
# RMSE: 5.205393882841976

# %%
#Multiple linear regression

# %%
#step1 independent and dependent variable creation
x=df[['TV','Radio','Newspaper']] # x variable contains all features/inputs
y=df.Sales # y is target

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
#step2 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()  #object creation
LR.fit(x_train,y_train)  #training of linear regression
y_predict=LR.predict(x_test)
print("R2: ",r2_score(y_test,y_predict))
# Out:
# R2:  0.9085774752313167

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 2.217151072541896
# MAE: 1.2114892606469103
# RMSE: 1.4890100982001082

# %%
x=df[['TV','Radio']] # x variable contains all features/inputs
y=df.Sales # y is target

# %%
x
# Out:
#         TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]

# %%
#step2 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()  #object creation
LR.fit(x_train,y_train)  #training of linear regression
y_predict=LR.predict(x_test)
print("R2: ",r2_score(y_test,y_predict))
# Out:
# R2:  0.9086623887492478

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 2.215091775909797
# MAE: 1.210808620492933
# RMSE: 1.4883184390142443
